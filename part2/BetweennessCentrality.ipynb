# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ZACHARY KARATE CLUB

# %%
G = nx.karate_club_graph()
print('#nodes:', len(G.nodes()), 'and', '#edges:', len(G.edges()))
# Out:
# #nodes: 34 and #edges: 78

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=300)
plt.title('Zachary Karate Club Network')
plt.show()

# %%
#Betweenness Centrality
betweenness_centrality = nx.betweenness_centrality(G)
print(betweenness_centrality)
# Out:
# {0: 0.43763528138528146, 1: 0.053936688311688304, 2: 0.14365680615680618, 3: 0.011909271284271283, 4: 0.0006313131313131313, 5: 0.02998737373737374, 6: 0.029987373737373736, 7: 0.0, 8: 0.05592682780182781, 9: 0.0008477633477633478, 10: 0.0006313131313131313, 11: 0.0, 12: 0.0, 13: 0.04586339586339586, 14: 0.0, 15: 0.0, 16: 0.0, 17: 0.0, 18: 0.0, 19: 0.03247504810004811, 20: 0.0, 21: 0.0, 22: 0.0, 23: 0.017613636363636363, 24: 0.0022095959595959595, 25: 0.0038404882154882154, 26: 0.0, 27: 0.02233345358345358, 28: 0.0017947330447330447, 29: 0.0029220779220779218, 30: 0.014411976911976909, 31: 0.13827561327561325, 32: 0.145247113997114, 33: 0.30407497594997596}

# %%
node_sizes = [3000 * centrality for centrality in betweenness_centrality.values()]
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=node_sizes)
plt.title('Zachary Karate Club Network (Node Sizes based on Betweenness Centrality)')
plt.show()

# %% [markdown]
# Dolphins Network

# %%
G = nx.read_edgelist("out.dolphins", create_using = nx.Graph(), nodetype = int)
print('#nodes:', len(G.nodes()), 'and', '#edges:', len(G.edges()))
# Out:
# #nodes: 62 and #edges: 159

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='orange', node_size=200 )

plt.title('Dolphins Network')
plt.show()

# %%
#Betweenness Centrality
betweenness_centrality = nx.betweenness_centrality(G)
print(betweenness_centrality)
# Out:
# {9: 0.022365737598409235, 4: 0.0023737965131407756, 10: 0.02089438036159347, 6: 0.004380300179480508, 7: 0.029372536747686685, 11: 0.016092020911693046, 1: 0.01908259621374376, 3: 0.00907281243346817, 14: 0.0528463284386915, 15: 0.06197200484885411, 16: 0.03329222098223321, 17: 0.0033047098620869104, 18: 0.11430016291546968, 2: 0.213324435532811, 19: 0.0148548997169549, 20: 0.013314394166853183, 8: 0.11823861926938342, 21: 0.10264573972090967, 22: 0.012700653930162124, 23: 0.0, 25: 0.0073830434896008665, 26: 0.0016441148408361526, 27: 0.004362477231329691, 28: 0.029236860493157976, 29: 0.06675695466395656, 30: 0.06552928249649563, 31: 0.03305046077177225, 32: 0.0, 33: 0.03278688524590164, 34: 0.057166440117259784, 13: 0.0, 35: 0.032694759702956426, 36: 0.0, 37: 0.24823719602893804, 24: 0.04218278563875618, 38: 0.13856978865859435, 39: 0.04535223883584539, 40: 0.070516778539934, 41: 0.14314951834261747, 42: 0.023251600670186168, 43: 0.029157951944837193, 44: 0.06283060442896508, 45: 0
# ...

# %%
node_sizes = [3000 * centrality for centrality in betweenness_centrality.values()]
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='orange', node_size=node_sizes)
plt.title('Dolphins Network (Node Sizes based on Degree Centrality)')
plt.show()
