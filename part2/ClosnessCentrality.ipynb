# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ZACHARY KARATE CLUB

# %%
G = nx.karate_club_graph()
print('#nodes:', len(G.nodes()), 'and', '#edges:', len(G.edges()))
# Out:
# #nodes: 34 and #edges: 78

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=300)
plt.title('Zachary Karate Club Network')
plt.show()

# %%
#Closeness Centrality
closeness_centrality = nx.closeness_centrality(G)
print(closeness_centrality)
# Out:
# {0: 0.5689655172413793, 1: 0.4852941176470588, 2: 0.559322033898305, 3: 0.4647887323943662, 4: 0.3793103448275862, 5: 0.38372093023255816, 6: 0.38372093023255816, 7: 0.44, 8: 0.515625, 9: 0.4342105263157895, 10: 0.3793103448275862, 11: 0.36666666666666664, 12: 0.3707865168539326, 13: 0.515625, 14: 0.3707865168539326, 15: 0.3707865168539326, 16: 0.28448275862068967, 17: 0.375, 18: 0.3707865168539326, 19: 0.5, 20: 0.3707865168539326, 21: 0.375, 22: 0.3707865168539326, 23: 0.39285714285714285, 24: 0.375, 25: 0.375, 26: 0.3626373626373626, 27: 0.4583333333333333, 28: 0.4520547945205479, 29: 0.38372093023255816, 30: 0.4583333333333333, 31: 0.5409836065573771, 32: 0.515625, 33: 0.55}

# %%
node_sizes = [3000 * centrality for centrality in closeness_centrality.values()]
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=node_sizes)
plt.title('Zachary Karate Club Network (Node Sizes based on Closeness Centrality)')
plt.show()

# %% [markdown]
# Dolphins Network

# %%
G = nx.read_edgelist("out.dolphins", create_using = nx.Graph(), nodetype = int)
print('#nodes:', len(G.nodes()), 'and', '#edges:', len(G.edges()))
# Out:
# #nodes: 62 and #edges: 159

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='orange', node_size=200 )

plt.title('Dolphins Network')
plt.show()

# %%
#Closeness Centrality
closeness_centrality = nx.closeness_centrality(G)
print(closeness_centrality)
# Out:
# {9: 0.3630952380952381, 4: 0.30808080808080807, 10: 0.25206611570247933, 6: 0.23828125, 7: 0.2675438596491228, 11: 0.3128205128205128, 1: 0.3465909090909091, 3: 0.2824074074074074, 14: 0.27111111111111114, 15: 0.3765432098765432, 16: 0.3388888888888889, 17: 0.32972972972972975, 18: 0.3096446700507614, 2: 0.3719512195121951, 19: 0.3370165745856354, 20: 0.3160621761658031, 8: 0.3652694610778443, 21: 0.391025641025641, 22: 0.3333333333333333, 23: 0.23735408560311283, 25: 0.3128205128205128, 26: 0.25523012552301255, 27: 0.2772727272727273, 28: 0.3160621761658031, 29: 0.3652694610778443, 30: 0.32275132275132273, 31: 0.32275132275132273, 32: 0.23735408560311283, 33: 0.21631205673758866, 34: 0.3652694610778443, 13: 0.2687224669603524, 35: 0.3160621761658031, 36: 0.24497991967871485, 37: 0.4178082191780822, 24: 0.3333333333333333, 38: 0.39869281045751637, 39: 0.32972972972972975, 40: 0.33516483516483514, 41: 0.40397350993377484, 42: 0.2975609756097561, 43: 0.32972972972972975, 44: 0.33701657
# ...

# %%
node_sizes = [3000 * centrality for centrality in closeness_centrality.values()]
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='orange', node_size=node_sizes)
plt.title('Dolphins Network (Node Sizes based on Closeness Centrality)')
plt.show()
