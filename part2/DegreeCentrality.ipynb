# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ZACHARY KARATE CLUB

# %%
G = nx.karate_club_graph()
print('#nodes:', len(G.nodes()), 'and', '#edges:', len(G.edges()))
# Out:
# #nodes: 34 and #edges: 78

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=300)
plt.title('Zachary Karate Club Network')
plt.show()

# %%
#Degree Centrality
degree_centrality = nx.degree_centrality(G)
print(degree_centrality)
# Out:
# {0: 0.48484848484848486, 1: 0.2727272727272727, 2: 0.30303030303030304, 3: 0.18181818181818182, 4: 0.09090909090909091, 5: 0.12121212121212122, 6: 0.12121212121212122, 7: 0.12121212121212122, 8: 0.15151515151515152, 9: 0.06060606060606061, 10: 0.09090909090909091, 11: 0.030303030303030304, 12: 0.06060606060606061, 13: 0.15151515151515152, 14: 0.06060606060606061, 15: 0.06060606060606061, 16: 0.06060606060606061, 17: 0.06060606060606061, 18: 0.06060606060606061, 19: 0.09090909090909091, 20: 0.06060606060606061, 21: 0.06060606060606061, 22: 0.06060606060606061, 23: 0.15151515151515152, 24: 0.09090909090909091, 25: 0.09090909090909091, 26: 0.06060606060606061, 27: 0.12121212121212122, 28: 0.09090909090909091, 29: 0.12121212121212122, 30: 0.12121212121212122, 31: 0.18181818181818182, 32: 0.36363636363636365, 33: 0.5151515151515151}

# %%
node_sizes = [3000 * centrality for centrality in degree_centrality.values()]
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=node_sizes)
plt.title('Zachary Karate Club Network (Node Sizes based on Degree Centrality)')
plt.show()

# %% [markdown]
# Dolphins Network

# %%
G = nx.read_edgelist("out.dolphins", create_using = nx.Graph(), nodetype = int)
print('#nodes:', len(G.nodes()), 'and', '#edges:', len(G.edges()))
# Out:
# #nodes: 62 and #edges: 159

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='orange', node_size=200 )

plt.title('Dolphins Network')
plt.show()

# %%
#Degree Centrality
degree_centrality = nx.degree_centrality(G)
print(degree_centrality)
# Out:
# {9: 0.09836065573770492, 4: 0.04918032786885246, 10: 0.11475409836065574, 6: 0.06557377049180328, 7: 0.09836065573770492, 11: 0.0819672131147541, 1: 0.09836065573770492, 3: 0.06557377049180328, 14: 0.13114754098360656, 15: 0.19672131147540983, 16: 0.11475409836065574, 17: 0.09836065573770492, 18: 0.14754098360655737, 2: 0.13114754098360656, 19: 0.11475409836065574, 20: 0.06557377049180328, 8: 0.0819672131147541, 21: 0.14754098360655737, 22: 0.09836065573770492, 23: 0.01639344262295082, 25: 0.09836065573770492, 26: 0.04918032786885246, 27: 0.04918032786885246, 28: 0.0819672131147541, 29: 0.0819672131147541, 30: 0.14754098360655737, 31: 0.0819672131147541, 32: 0.01639344262295082, 33: 0.04918032786885246, 34: 0.1639344262295082, 13: 0.01639344262295082, 35: 0.0819672131147541, 36: 0.01639344262295082, 37: 0.11475409836065574, 24: 0.04918032786885246, 38: 0.18032786885245902, 39: 0.13114754098360656, 40: 0.03278688524590164, 41: 0.13114754098360656, 42: 0.0819672131147541, 43: 0.09836065573770492, 44: 0.11475409836065574, 45: 0.06557377049180328, 46: 0.18032786885245902, 47: 0.03278688524590164, 48: 0.09836065573770492, 50: 0.03278688524590164, 51: 0.11475409836065574, 52: 0.1639344262295082, 5: 0.01639344262295082, 12: 0.01639344262295082, 53: 0.06557377049180328, 54: 0.03278688524590164, 55: 0.11475409836065574, 56: 0.03278688524590164, 57: 0.03278688524590164, 58: 0.14754098360655737, 49: 0.01639344262295082, 59: 0.01639344262295082, 60: 0.0819672131147541, 61: 0.01639344262295082, 62: 0.04918032786885246}

# %%
node_sizes = [3000 * centrality for centrality in degree_centrality.values()]
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='orange', node_size=node_sizes)
plt.title('Dolphins Network (Node Sizes based on Degree Centrality)')
plt.show()
